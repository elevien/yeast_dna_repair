# %%
using CSV, DataFrames, StatsBase, PyPlot
PyPlot.svg(true)
# Out:
# true

# %%
data = CSV.read("./../../experimental_data/processed_data/all_experiments.csv", DataFrame);
nuclease = "SpCas9"
defect = "CGG"
chain = CSV.read(pwd()*"/output/$(defect)_$(nuclease)_chain.csv", DataFrame);
df = data[(data.nuclease .== nuclease) .& (data.defect .== defect),:]
df_bulk = combine(groupby(df,:time), :bf => sum => :bf,:gfp => sum => :gfp)
# ODE_sols = []
# for k in 1:10
#     ode_sol = CSV.read(pwd()*"/output/NR_SpCas9_ode_sol_$k.csv", DataFrame,header = [:gfp,:bf,:dsb],skipto=2);

# %%
fig, ax = plt.subplots(figsize=(8,3))
ode_sol = CSV.read(pwd()*"/output/$(defect)_$(nuclease)_ode_sol_20.csv"
    , DataFrame,header = [:gfp,:bf,:dsb],skipto=2);
plt.plot(ode_sol.gfp ./ ode_sol.bf)
ode_sol = CSV.read(pwd()*"/output/$(defect)_$(nuclease)_ode_sol_1.csv"
    , DataFrame,header = [:gfp,:bf,:dsb],skipto=2);
plt.plot(ode_sol.gfp ./ ode_sol.bf )
plt.plot(df_bulk.gfp ./ df_bulk.bf)
# Out:
# Figure(PyObject <Figure size 800x300 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x1c52d34c0>

# %%
df
# Out:
# 6048×7 DataFrame
#   Row │ well   bf     gfp    time   experiment  defect   nuclease
#       │ Int64  Int64  Int64  Int64  String15    String3  String7
# ──────┼───────────────────────────────────────────────────────────
#     1 │     1      1      0      0  CTG_SpCas9  CTG      SpCas9
#     2 │     1      1      0     20  CTG_SpCas9  CTG      SpCas9
#     3 │     1      1      0     40  CTG_SpCas9  CTG      SpCas9
#     4 │     1      1      0     60  CTG_SpCas9  CTG      SpCas9
#     5 │     1      1      0     80  CTG_SpCas9  CTG      SpCas9
#     6 │     1      1      0    100  CTG_SpCas9  CTG      SpCas9
#     7 │     1      1      0    120  CTG_SpCas9  CTG      SpCas9
#     8 │     1      1      0    140  CTG_SpCas9  CTG      SpCas9
#     9 │     1      1      0    160  CTG_SpCas9  CTG      SpCas9
#    10 │     1      1      0    180  CTG_SpCas9  CTG      SpCas9
#    11 │     1      1      0    200  CTG_SpCas9  CTG      SpCas9
# ...

# %%
@doc combine
# Out:
#   combine(df::AbstractDataFrame, args...; renamecols::Bool=true)
#   combine(f::Callable, df::AbstractDataFrame; renamecols::Bool=true)
#   combine(gd::GroupedDataFrame, args...;
#           keepkeys::Bool=true, ungroup::Bool=true, renamecols::Bool=true)
#   combine(f::Base.Callable, gd::GroupedDataFrame;
#           keepkeys::Bool=true, ungroup::Bool=true, renamecols::Bool=true)
#
#   Create a new data frame that contains columns from df or gd specified by
#   args and return it. The result can have any number of rows that is
#   determined by the values returned by passed transformations.
#
#   Below detailed common rules for all transformation functions supported by
#   DataFrames.jl are explained and compared.
#
#   All these operations are supported both for AbstractDataFrame (when split
#   and combine steps are skipped) and GroupedDataFrame. Technically,
#   AbstractDataFrame is just considered as being grouped on no columns (meaning
# ...
